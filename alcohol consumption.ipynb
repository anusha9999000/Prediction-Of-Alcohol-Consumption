# %%
import os

# %%
os.chdir("/Users/user/Desktop/DATA SETS")

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv("Alcoholconsumption1.csv")

# %%
data
# Out:
#          Name Sex  Age                Email   Salary  Unemployed Occupation  \
# 0       Aadya   F   24      aadya@gmail.com        0           1    student
# 1        Anil   M   28       anil@gmail.com        0           1       idle
# 2        Adit   M   22       adit@gmail.com        0           1    student
# 3      Anjali   F   40     anjali@gmail.com  1000000           0   engineer
# 4      Vihaan   M   24     vihaan@gmail.com        0           1       idle
# 5       Rahul   M   36      rahul@gmail.com   600000           0     doctor
# 6       Vinay   M   23      vinay@gmail.com        0           1       idle
# 7      Nikhil   M   39     nikhil@gmail.com  1200000           0   engineer
# 8         Sai   M   20        sai@gmail.com        0           1    student
# 9        Deva   M   20       deva@gmail.com        0           1    student
# 10     Vasavi   F   28     vasavi@gmail.com   800000           0     doctor
# ...

# %%
data.describe()
# Out:
#              Age        Salary  Unemployed  Family size  Tax_collection  \
# count  53.000000  5.300000e+01   53.000000    53.000000       53.000000
# mean   29.660377  5.502094e+05    0.528302     5.150943     3756.326792
# std    10.964880  1.147197e+06    0.503975     1.419591     1731.994785
# min    18.000000  0.000000e+00    0.000000     2.000000     1092.960000
# 25%    22.000000  0.000000e+00    0.000000     4.000000     2470.000000
# 50%    25.000000  0.000000e+00    1.000000     5.000000     3600.000000
# 75%    34.000000  6.000000e+05    1.000000     6.000000     4940.000000
# max    67.000000  7.000000e+06    1.000000     8.000000     8740.000000
#
#        Alcohol_Consumption
# count            53.000000
# mean             22.113208
# std               9.552809
# min               8.000000
# 25%              13.000000
# 50%              22.000000
# 75%              28.000000
# max              46.000000

# %%
data.corr()
# Out:
#                           Age    Salary  Unemployed  Family size  \
# Age                  1.000000  0.443371   -0.624633    -0.031236
# Salary               0.443371  1.000000   -0.512431     0.104814
# Unemployed          -0.624633 -0.512431    1.000000    -0.113605
# Family size         -0.031236  0.104814   -0.113605     1.000000
# Tax_collection      -0.235772  0.057721    0.087280     0.078682
# Alcohol_Consumption -0.298703  0.007640    0.127144     0.054021
#
#                      Tax_collection  Alcohol_Consumption
# Age                       -0.235772            -0.298703
# Salary                     0.057721             0.007640
# Unemployed                 0.087280             0.127144
# Family size                0.078682             0.054021
# Tax_collection             1.000000             0.946701
# Alcohol_Consumption        0.946701             1.000000

# %%
Tax=data['Tax_collection']

# %%
Tax
# Out:
# 0     2049.30
# 1     2160.00
# 2     2732.40
# 3     2340.00
# 4     3005.64
# 5     2660.00
# 6     5700.00
# 7     3142.26
# 8     6300.00
# 9     6270.00
# 10    1366.20
# 11    5400.00
# 12    8740.00
# 13    1980.00
# 14    3005.00
# 15    1800.00
# 16    3600.00
# 17    1502.82
# 18    6650.00
# 19    6840.00
# 20    1496.00
# 21    5320.00
# 22    5464.80
# 23    3800.00
# 24    1620.00
# 25    3278.88
# 26    2470.00
# 27    4140.00
# 28    6147.90
# 29    6840.00
# 30    4680.00
# 31    2732.40
# 32    4750.00
# 33    4940.00
# 34    2700.00
# 35    3600.00
# 36    3600.00
# 37    3990.00
# 38    5400.00
# 39    4500.00
# 40    3142.26
# 41    2470.00
# 42    4180.00
# 43    5400.00
# 44    3415.50
# 45    1900.00
# 46    3960.00
# 47    2090.00
# 48    4098.60
# 49    4180.00
# 50    1092.96
# 51    1710.00
# 52    2732.40
# Name: Tax_collection, dtype: float64

# %%
Alcohol=data['Alcohol_Consumption']

# %%
Alcohol
# Out:
# 0     15
# 1     12
# 2     20
# 3     13
# 4     22
# 5     14
# 6     30
# 7     23
# 8     35
# 9     33
# 10    10
# 11    30
# 12    46
# 13    11
# 14    22
# 15    10
# 16    20
# 17    11
# 18    35
# 19    38
# 20    11
# 21    28
# 22    40
# 23    20
# 24     9
# 25    24
# 26    13
# 27    23
# 28    45
# 29    36
# 30    26
# 31    20
# 32    25
# 33    26
# 34    15
# 35    20
# 36    20
# 37    21
# 38    30
# 39    25
# 40    23
# 41    13
# 42    22
# 43    30
# 44    25
# 45    10
# 46    22
# 47    11
# 48    30
# 49    22
# 50     8
# 51     9
# 52    20
# Name: Alcohol_Consumption, dtype: int64

# %%
ax=plt.plot(Tax,Alcohol,'o')
plt.xlabel("Tax_collection")
plt.ylabel("Alcohol_consumption")
# Out:
# Text(0, 0.5, 'Alcohol_consumption')

# %%
Mean_alcohol=data['Alcohol_Consumption'].mean()

# %%
Mean_alcohol
# Out:
# 22.11320754716981

# %%
ax=plt.plot(Tax,Alcohol,'o')
plt.xlabel("Tax_collection")
plt.ylabel("Alcohol_consumption")
plt.axhline(Mean_alcohol, color='r', linestyle='-')
plt.show()

# %%
import statsmodels.api as sm
model=sm.OLS(Alcohol,Tax).fit()

# %%
#obtain model summary
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Alcohol_Consumption   R-squared:                       0.982
# Model:                             OLS   Adj. R-squared:                  0.982
# Method:                  Least Squares   F-statistic:                     2850.
# Date:                 Tue, 25 Jun 2019   Prob (F-statistic):           4.30e-47
# Time:                         09:56:36   Log-Likelihood:                -137.18
# No. Observations:                   53   AIC:                             276.4
# Df Residuals:                       52   BIC:                             278.3
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
sns.pairplot(data)

# %%
sns.distplot(Tax)

# %%
sns.distplot(data['Salary'])

# %%
sns.distplot(data['Unemployed'])

# %%
# Plot the correlation usinf heatmap
corr = data.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
#Plot a regression line
plt.plot(Tax,Alcohol,'o')
plt.ylabel("Alcohol_consumption")
plt.xlabel("Tax_collection")
plt.axhline(Mean_alcohol, color='r', linestyle='-')
#regression plot
sns.regplot(x='Tax_collection', y='Alcohol_Consumption', data=data)

# %%
salary=data['Salary']

# %%
salary
# Out:
# 0           0
# 1           0
# 2           0
# 3     1000000
# 4           0
# 5      600000
# 6           0
# 7     1200000
# 8           0
# 9           0
# 10     800000
# 11          0
# 12     250000
# 13          0
# 14          0
# 15          0
# 16     450000
# 17     600000
# 18    2000000
# 19          0
# 20          0
# 21     350000
# 22          0
# 23          0
# 24     500000
# 25     550000
# 26    1300000
# 27          0
# 28     111100
# 29          0
# 30    7000000
# 31          0
# 32    3000000
# 33    1000000
# 34     250000
# 35    3300000
# 36          0
# 37     900000
# 38          0
# 39          0
# 40          0
# 41          0
# 42    1000000
# 43          0
# 44    1200000
# 45          0
# 46     400000
# 47     500000
# 48          0
# 49          0
# 50     350000
# 51     550000
# 52          0
# Name: Salary, dtype: int64

# %%
mean_salary=data['Salary'].mean()

# %%
mean_salary
# Out:
# 550209.4339622641

# %%
#Plot a regression line
plt.plot(salary,Alcohol,'o')
plt.ylabel("Alcohol_consumption")
plt.xlabel("salary")
plt.axhline(Mean_alcohol, color='r', linestyle='-')
#regression plot
sns.regplot(x='Salary', y='Alcohol_Consumption', data=data)

# %%
unemp=data['Unemployed']

# %%
unemp
# Out:
# 0     1
# 1     1
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    1
# 15    1
# 16    0
# 17    0
# 18    0
# 19    1
# 20    1
# 21    0
# 22    1
# 23    1
# 24    0
# 25    0
# 26    0
# 27    1
# 28    0
# 29    1
# 30    0
# 31    1
# 32    0
# 33    0
# 34    0
# 35    0
# 36    1
# 37    0
# 38    1
# 39    1
# 40    1
# 41    1
# 42    0
# 43    1
# 44    0
# 45    1
# 46    0
# 47    0
# 48    1
# 49    1
# 50    0
# 51    0
# 52    1
# Name: Unemployed, dtype: int64

# %%
#Plot a regression line
plt.plot(unemp,Alcohol,'o')
plt.ylabel("Alcohol_consumption")
plt.xlabel("unemployement")
plt.axhline(Mean_alcohol, color='r', linestyle='-')
#regression plot
sns.regplot(x='Unemployed', y='Alcohol_Consumption', data=data)

# %%
X=Tax
y=Alcohol

# %%
X
# Out:
# 0     2049.30
# 1     2160.00
# 2     2732.40
# 3     2340.00
# 4     3005.64
# 5     2660.00
# 6     5700.00
# 7     3142.26
# 8     6300.00
# 9     6270.00
# 10    1366.20
# 11    5400.00
# 12    8740.00
# 13    1980.00
# 14    3005.00
# 15    1800.00
# 16    3600.00
# 17    1502.82
# 18    6650.00
# 19    6840.00
# 20    1496.00
# 21    5320.00
# 22    5464.80
# 23    3800.00
# 24    1620.00
# 25    3278.88
# 26    2470.00
# 27    4140.00
# 28    6147.90
# 29    6840.00
# 30    4680.00
# 31    2732.40
# 32    4750.00
# 33    4940.00
# 34    2700.00
# 35    3600.00
# 36    3600.00
# 37    3990.00
# 38    5400.00
# 39    4500.00
# 40    3142.26
# 41    2470.00
# 42    4180.00
# 43    5400.00
# 44    3415.50
# 45    1900.00
# 46    3960.00
# 47    2090.00
# 48    4098.60
# 49    4180.00
# 50    1092.96
# 51    1710.00
# 52    2732.40
# Name: Tax_collection, dtype: float64

# %%
y
# Out:
# 0     15
# 1     12
# 2     20
# 3     13
# 4     22
# 5     14
# 6     30
# 7     23
# 8     35
# 9     33
# 10    10
# 11    30
# 12    46
# 13    11
# 14    22
# 15    10
# 16    20
# 17    11
# 18    35
# 19    38
# 20    11
# 21    28
# 22    40
# 23    20
# 24     9
# 25    24
# 26    13
# 27    23
# 28    45
# 29    36
# 30    26
# 31    20
# 32    25
# 33    26
# 34    15
# 35    20
# 36    20
# 37    21
# 38    30
# 39    25
# 40    23
# 41    13
# 42    22
# 43    30
# 44    25
# 45    10
# 46    22
# 47    11
# 48    30
# 49    22
# 50     8
# 51     9
# 52    20
# Name: Alcohol_Consumption, dtype: int64

# %%
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.

# %%
X_train
# Out:
# 24    1620.00
# 42    4180.00
# 40    3142.26
# 35    3600.00
# 26    2470.00
# 13    1980.00
# 22    5464.80
# 44    3415.50
# 27    4140.00
# 17    1502.82
# 48    4098.60
# 33    4940.00
# 23    3800.00
# 4     3005.64
# 36    3600.00
# 14    3005.00
# 29    6840.00
# 28    6147.90
# 47    2090.00
# 52    2732.40
# 18    6650.00
# 20    1496.00
# 25    3278.88
# 6     5700.00
# 7     3142.26
# 50    1092.96
# 1     2160.00
# 16    3600.00
# 0     2049.30
# 15    1800.00
# 5     2660.00
# 11    5400.00
# 9     6270.00
# 8     6300.00
# 12    8740.00
# 43    5400.00
# 37    3990.00
# Name: Tax_collection, dtype: float64

# %%
y_train
# Out:
# 24     9
# 42    22
# 40    23
# 35    20
# 26    13
# 13    11
# 22    40
# 44    25
# 27    23
# 17    11
# 48    30
# 33    26
# 23    20
# 4     22
# 36    20
# 14    22
# 29    36
# 28    45
# 47    11
# 52    20
# 18    35
# 20    11
# 25    24
# 6     30
# 7     23
# 50     8
# 1     12
# 16    20
# 0     15
# 15    10
# 5     14
# 11    30
# 9     33
# 8     35
# 12    46
# 43    30
# 37    21
# Name: Alcohol_Consumption, dtype: int64

# %%
X_train = X_train.values.reshape((-1,1))

# %%
X_train
# Out:
# array([[1620.  ],
#        [4180.  ],
#        [3142.26],
#        [3600.  ],
#        [2470.  ],
#        [1980.  ],
#        [5464.8 ],
#        [3415.5 ],
#        [4140.  ],
#        [1502.82],
#        [4098.6 ],
#        [4940.  ],
#        [3800.  ],
#        [3005.64],
#        [3600.  ],
#        [3005.  ],
#        [6840.  ],
#        [6147.9 ],
#        [2090.  ],
#        [2732.4 ],
#        [6650.  ],
#        [1496.  ],
#        [3278.88],
#        [5700.  ],
#        [3142.26],
#        [1092.96],
#        [2160.  ],
#        [3600.  ],
#        [2049.3 ],
#        [1800.  ],
#        [2660.  ],
#        [5400.  ],
#        [6270.  ],
#        [6300.  ],
#        [8740.  ],
#        [5400.  ],
#        [3990.  ]])

# %%
#linear regression with sklearn
#tax collection vs Alcohol Consumption
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy = model.score(X_train, y_train)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.8842286162812858

# %%
#Print coefficients
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 2.8851036118479527
# slope: [0.00522423]

# %%
X_test
# Out:
# 30    4680.0
# 2     2732.4
# 51    1710.0
# 32    4750.0
# 31    2732.4
# 46    3960.0
# 34    2700.0
# 39    4500.0
# 45    1900.0
# 19    6840.0
# 10    1366.2
# 3     2340.0
# 21    5320.0
# 49    4180.0
# 38    5400.0
# 41    2470.0
# Name: Tax_collection, dtype: float64

# %%
y_test
# Out:
# 30    26
# 2     20
# 51     9
# 32    25
# 31    20
# 46    22
# 34    15
# 39    25
# 45    10
# 19    38
# 10    10
# 3     13
# 21    28
# 49    22
# 38    30
# 41    13
# Name: Alcohol_Consumption, dtype: int64

# %%
X_test = X_test.values.reshape((-1,1))

# %%
X_test
# Out:
# array([[4680. ],
#        [2732.4],
#        [1710. ],
#        [4750. ],
#        [2732.4],
#        [3960. ],
#        [2700. ],
#        [4500. ],
#        [1900. ],
#        [6840. ],
#        [1366.2],
#        [2340. ],
#        [5320. ],
#        [4180. ],
#        [5400. ],
#        [2470. ]])

# %%
#Predictions from the model
predictions = model.predict(X_test)
print('predicted Acohol Consumptions:',predictions, sep = '\n')
# Out:
# predicted Acohol Consumptions:
# [27.33450175 17.15979068 11.81853755 27.70019788 17.15979068 23.57305589
#  16.99052562 26.39414029 12.81114132 38.61883936 10.02244715 15.10980268
#  30.67800919 24.72238657 31.09594762 15.78895263]

# %%
y_test
# Out:
# 30    26
# 2     20
# 51     9
# 32    25
# 31    20
# 46    22
# 34    15
# 39    25
# 45    10
# 19    38
# 10    10
# 3     13
# 21    28
# 49    22
# 38    30
# 41    13
# Name: Alcohol_Consumption, dtype: int64

# %%
#Visualize the predictions
plt.scatter(y_test, predictions)

# %%
#Evaluating the model 
from sklearn.metrics import mean_squared_error, r2_score
X_train = X_train.reshape(-1,1)
y_train_prediction = model.predict(X_train)

X_test = X_test.reshape(-1,1)
y_test_prediction = model.predict(X_test)

# %%
# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")

# model evaluation for training set
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")

# model evaluation for testing set
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)

print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# Slope: [0.00522423]
# Intercept: 2.8851036118479527
#
#
# The model performance for training set
# --------------------------------------
# RMSE is 3.3805270691583025
# R2 score is 0.8842286162812858
#
#
# The model performance for testing set
# --------------------------------------
# Root mean squared error:  2.2055292494522254
# R2 score:  0.9239758258138914

# %%
#MultiLinear Regression

# %%
X = data[["Tax_collection", "Unemployed"]]
y = data["Alcohol_Consumption"]

# %%
X
# Out:
#     Tax_collection  Unemployed
# 0          2049.30           1
# 1          2160.00           1
# 2          2732.40           1
# 3          2340.00           0
# 4          3005.64           1
# 5          2660.00           0
# 6          5700.00           1
# 7          3142.26           0
# 8          6300.00           1
# 9          6270.00           1
# 10         1366.20           0
# 11         5400.00           1
# 12         8740.00           0
# 13         1980.00           1
# 14         3005.00           1
# 15         1800.00           1
# 16         3600.00           0
# 17         1502.82           0
# 18         6650.00           0
# 19         6840.00           1
# 20         1496.00           1
# 21         5320.00           0
# 22         5464.80           1
# 23         3800.00           1
# 24         1620.00           0
# 25         3278.88           0
# 26         2470.00           0
# 27         4140.00           1
# 28         6147.90           0
# ...

# %%
y
# Out:
# 0     15
# 1     12
# 2     20
# 3     13
# 4     22
# 5     14
# 6     30
# 7     23
# 8     35
# 9     33
# 10    10
# 11    30
# 12    46
# 13    11
# 14    22
# 15    10
# 16    20
# 17    11
# 18    35
# 19    38
# 20    11
# 21    28
# 22    40
# 23    20
# 24     9
# 25    24
# 26    13
# 27    23
# 28    45
# 29    36
# 30    26
# 31    20
# 32    25
# 33    26
# 34    15
# 35    20
# 36    20
# 37    21
# 38    30
# 39    25
# 40    23
# 41    13
# 42    22
# 43    30
# 44    25
# 45    10
# 46    22
# 47    11
# 48    30
# 49    22
# 50     8
# 51     9
# 52    20
# Name: Alcohol_Consumption, dtype: int64

# %%
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Alcohol_Consumption   R-squared:                       0.983
# Model:                             OLS   Adj. R-squared:                  0.982
# Method:                  Least Squares   F-statistic:                     1479.
# Date:                 Tue, 25 Jun 2019   Prob (F-statistic):           6.95e-46
# Time:                         10:28:49   Log-Likelihood:                -135.70
# No. Observations:                   53   AIC:                             275.4
# Df Residuals:                       51   BIC:                             279.3
# Df Model:                            2
# Covariance Type:             nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=1)

# %%
# define the data/predictors as the pre-set feature names  
features = X_train.iloc[:,:].values

# %%
labels = y_train.iloc[:].values

# %%
X=features
y=labels

# %%
# Instantiate Multiple linear regrssion model
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
#Check model accuracy
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.8852349083133327

# %%
#Visualize the predictions
plt.scatter(y, predictions)

# %%
#Evaluating the model 
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [0.00521408 0.63347073]
# Intercept: 2.5814891112695832
#
#
# The model performance
# --------------------------------------
# RMSE is 3.3658031287295405
# R2 score is 0.8852349083133328
